# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import cv2
import os

# %%
#reading data and labels
seismic_data = np.load('train_seismic.npy') 
seismic_data_labels = np.load('train_labels.npy')

# %%
#got these details from the research paper
iline, xline, depth = seismic_data.shape
print((iline, xline, depth))
# Out:
# (401, 701, 255)

# %%
#VErsion1: for section data
#wrt to "xline" true images 
#It will generate 701 images each of size 401*255
for i in range(0, xline):
    plt.imsave("trainData/trainX/seismic/train_{}.jpg".format(i), seismic_data[:,i,:])

    img = cv2.imread("trainData/trainX/seismic/train_{}.jpgg".format(i))
    img_rotate_90_counterclockwise = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
    cv2.imwrite("trainData/trainX/seismic/train_{}.jpg".format(i), img_rotate_90_counterclockwise)

# %%
#wrt to "xline" labels
for i in range(0, iline):
    plt.imsave("trainData/trainX/label/train_{}.jpg".format(i), seismic_data[i,:,:])

    img = cv2.imread("trainData/trainX/label/train_{}.jpg".format(i))
    img_rotate_90_counterclockwise = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
    cv2.imwrite("ttrainData/trainX/label/train_{}.jpg".format(i), img_rotate_90_counterclockwise)

# %%
#wrt to "iline" true images
#It will generate 401 images each of size 701*255
for i in range(0, iline):
    plt.imsave("trainData/trainI/seismic/train_{}.jpg".format(i), seismic_data_labels[i,:,:])

    img = cv2.imread("trainData/trainI/seismic/train_{}.jpg".format(i))
    img_rotate_90_counterclockwise = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
    cv2.imwrite("trainData/trainI/seismic/train_{}.jpg".format(i), img_rotate_90_counterclockwise)

# %%
#wrt to "iline" labels
for i in range(0, xline):
    plt.imsave("trainData/trainI/label/train_{}.jpg".format(i), seismic_data_labels[:,i,:])

    img = cv2.imread("trainData/trainI/label/train_{}.jpg".format(i))
    img_rotate_90_counterclockwise = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
    cv2.imwrite("trainData/trainI/label/train_{}.jpg".format(i), img_rotate_90_counterclockwise)

# %%
lines
# Out:
# ['i_17_450_200\n',
#  'x_50_528_100\n',
#  'i_244_150_50\n',
#  'i_284_350_50\n',
#  'x_350_126_50\n',
#  'x_300_215_200\n',
#  'i_217_50_100\n',
#  'x_0_254_100\n',
#  'x_150_421_100\n',
#  'x_0_195_50\n',
#  'i_211_150_50\n',
#  'i_159_500_150\n',
#  'i_142_0_200\n',
#  'i_13_300_200\n',
#  'x_150_15_0\n',
#  'i_300_500_0\n',
#  'i_24_650_200\n',
#  'x_50_426_150\n',
#  'x_0_548_100\n',
#  'x_350_476_200\n',
#  'i_309_400_100\n',
#  'i_48_350_50\n',
#  'i_217_150_200\n',
#  'i_226_350_0\n',
#  'i_184_150_150\n',
#  'x_300_314_50\n',
#  'x_250_162_150\n',
#  'x_200_365_150\n',
#  'i_248_100_50\n',
#  'i_396_350_200\n',
#  'x_300_657_0\n',
#  'i_243_600_0\n',
#  'x_150_376_0\n',
#  'x_150_449_150\n',
#  'i_333_250_50\n',
#  'i_109_150_100\n',
#  'i_314_300_150\n',
#  'x_150_542_100\n',
#  'i_347_100_50\n',
#  'x_200_600_50\n',
#  'x_350_114_200\n',
#  'x_200_486_200\n',
#  'i_302_50_100\n',
#  'x_150_86_0\n',
#  'x_50_173_0\n',
#  'x_250_548_200\n',
#  'x_50_609_200\n',
# ...

# %%
with open('patch_train.txt') as file_in:
    for line in file_in:
        patch_name = line
        direction, idx, xdx, ddx = patch_name.split(sep='_')
        idx, xdx, ddx = int(idx), int(xdx), int(ddx)
        patch_size = 99
        
        if direction == 'i':
            im = seismic_data[idx, xdx:xdx+patch_size, ddx:ddx+patch_size]
            lbl = seismic_data_labels[idx, xdx:xdx+patch_size, ddx:ddx+patch_size]
            
        elif direction == 'x':    
            im = seismic_data[idx: idx+patch_size, xdx, ddx:ddx+patch_size]
            lbl = seismic_data_labels[idx: idx+patch_size, xdx, ddx:ddx+patch_size]

        my_string = str(direction)+ '_' + str(idx) +'_' + str(xdx) +'_' + str(ddx)
        plt.imsave("trainData/trainX/seismic/{}.png".format(my_string), im)
        plt.imsave("trainData/trainX/labels/{}.png".format(my_string), lbl)

# %%
print(i)
# Out:
# 44888

# %%
#code to rotate and store generated images and their labels
input_folder = "trainData/trainX/seismic/"
output_folder = "Rotated_trainData/trainX/seismic/"

for i in os.listdir(input_folder):
    img = cv2.imread(input_folder + i)
    img_rotate_90_counterclockwise = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
    cv2.imwrite(output_folder + i, img_rotate_90_counterclockwise)

# %%
#now rotating the labels of images
input_folder = "trainData/trainX/labels/"
output_folder = "Rotated_trainData/trainX/labels/"

for i in os.listdir(input_folder):
    img = cv2.imread(input_folder + i)
    img_rotate_90_counterclockwise = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
    cv2.imwrite(output_folder + i, img_rotate_90_counterclockwise)

# %%
###RUN THE CODE FROM HERE.Check the path before running.

import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import cv2
import os

# %%
#reading data and labels
seismic_data = np.load('train_seismic.npy') 
seismic_data_labels = np.load('train_labels.npy')

# %%
with open('val.txt') as file_in:
    for line in file_in:
        patch_name = line
        direction, idx, xdx, ddx = patch_name.split(sep='_')
        idx, xdx, ddx = int(idx), int(xdx), int(ddx)
        patch_size = 99
        
        if direction == 'i':
            im = seismic_data[idx, xdx:xdx+patch_size, ddx:ddx+patch_size]
            lbl = seismic_data_labels[idx, xdx:xdx+patch_size, ddx:ddx+patch_size]
            
        elif direction == 'x':    
            im = seismic_data[idx: idx+patch_size, xdx, ddx:ddx+patch_size]
            lbl = seismic_data_labels[idx: idx+patch_size, xdx, ddx:ddx+patch_size]

        my_string = str(direction)+ '_' + str(idx) +'_' + str(xdx) +'_' + str(ddx)
        plt.imsave("trainData/trainX/seismic/{}.png".format(my_string), im)
        plt.imsave("trainData/trainX/labels/{}.png".format(my_string), lbl)

# %%
#code to rotate and store generated images and their labels
input_folder = "trainData/trainX/seismic/"
output_folder = "Rotated_trainData/trainX/seismic/"

for i in os.listdir(input_folder):
    img = cv2.imread(input_folder + i)
    img_rotate_90_counterclockwise = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
    cv2.imwrite(output_folder + i, img_rotate_90_counterclockwise)

# %%
#now rotating the labels of images
input_folder = "trainData/trainX/labels/"
output_folder = "Rotated_trainData/trainX/labels/"

for i in os.listdir(input_folder):
    img = cv2.imread(input_folder + i)
    img_rotate_90_counterclockwise = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
    cv2.imwrite(output_folder + i, img_rotate_90_counterclockwise)
