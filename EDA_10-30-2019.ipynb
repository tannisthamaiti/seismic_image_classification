# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
seismic_data = np.load('data/train/train_seismic.npy') 
seismic_data_labels = np.load('data/train/train_labels.npy')

# %%
#shape 
seismic_data.shape
# Out:
# (401, 701, 255)

# %%
seismic_data_labels.shape
# Out:
# (401, 701, 255)

# %% [markdown]
# ## Plot seismic sections in in-line

# %%
plt.figure(figsize=(12, 6))
plt.subplot(221)
plt.imshow(seismic_data[:,16,:])

plt.subplot(222)
plt.imshow(seismic_data_labels[:,16,:])
plt.show()
